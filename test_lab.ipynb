# %%
from matplotlib import pyplot as plt
import numpy as np
# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()
# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import a_python_script

# %%
a_python_script.days_of_the_week
# Out:
# 7

# %%
a_python_script.say_hello("Annabelle")
# Out:
# Hello, world! Hello Annabelle
# 'Annabelle'

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is BCD3-6A11
#
#  Directory of C:\Users\s1111172\Documents\PLUS_softwaredev_2025_Annabelle_Kiefer
#
# 03/24/2025  11:55 AM    <DIR>          .
# 03/24/2025  11:55 AM    <DIR>          ..
# 03/24/2025  11:53 AM    <DIR>          .ipynb_checkpoints
# 03/24/2025  10:56 AM               263 amna-favorites.md
# 03/24/2025  10:56 AM               235 arunima
# 03/24/2025  11:53 AM               174 a_python_script.py
