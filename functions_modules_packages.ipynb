# %%
#Assign a variable a list containing at least 4 integers

list1=[3,12,4,67]

# %%
#Try out min(), max(), sum() on the list.
print(min(list1))
print(max(list1))
print(sum(list1))
# Out:
# 3
# 67
# 86

# %%
#Try out abs() using both a positive and negative number
positive=10
negative=-10
print(abs(positive))
print(abs(negative))
# Out:
# 10
# 10

# %%
#Return the 9 to the 4th power using pow()
print(pow(9,4))
# Out:
# 6561

# %%
#Create a list, tuple and dictionary containing at least three
#items each, and assign each of them to a variable.

list2=[10, 11, 33]
tuple1=["German", "French", "Spanish"]
dict1={"Name": "Anna", "Age": 23, "Country": "Germany"}

# %%
#Return the length of each variable using len()
print(len(list2))
print(len(tuple1))
print(len(dict1))
# Out:
# 3
# 3
# 3

# %%
#See what happens when you use the sorted() function!
print(sorted(list2, reverse=True))
print(sorted(tuple1))
print(sorted(dict1))
# Out:
# [33, 11, 10]
# ['French', 'German', 'Spanish']
# ['Age', 'Country', 'Name']

# %%
#See what is returned when you call: dir(), globals(),
#locals(), vars()
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_13',
#  '_14',
#  '_16',
#  '_2',
#  '_21',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'dict1',
#  'exit',
#  'get_ipython',
#  'list',
#  'list1',
#  'list2',
#  'negative',
#  'positive',
#  'quit',
#  'tuple1']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '#Assign a variable a list containing at least 4 integers\n\nlist=[3,12,4,67]',
#   'min(list)\nmax(list)\nsum(list)',
#   'min(list)\nprint\nmax(list)\nprint\nsum(list)\nprint',
#   'min(list)\n    print\nmax(list)\n    print\nsum(list)\n    print',
#   'min(list)\n    print()\nmax(list)\n    print()\nsum(list)\n    print()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'positive=10\nnegative=-10\nprint(abs(positive))\nprint(abs(negative))',
#   'print(min(list1))\nprint(max(list1))\nprint(sum(list1))',
#   '#Assign a variable a list containing at least 4 integers\n\nlist1=[3,12,4,67]',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '#Assign a variable a list containing at least 4 integers\n\nlist=[3,12,4,67]',
#   'min(list)\nmax(list)\nsum(list)',
#   'min(list)\nprint\nmax(list)\nprint\nsum(list)\nprint',
#   'min(list)\n    print\nmax(list)\n    print\nsum(list)\n    print',
#   'min(list)\n    print()\nmax(list)\n    print()\nsum(list)\n    print()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'positive=10\nnegative=-10\nprint(abs(positive))\nprint(abs(negative))',
#   'print(min(list1))\nprint(max(list1))\nprint(sum(list1))',
#   '#Assign a variable a list containing at least 4 integers\n\nlist1=[3,12,4,67]',
# ...

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '#Assign a variable a list containing at least 4 integers\n\nlist=[3,12,4,67]',
#   'min(list)\nmax(list)\nsum(list)',
#   'min(list)\nprint\nmax(list)\nprint\nsum(list)\nprint',
#   'min(list)\n    print\nmax(list)\n    print\nsum(list)\n    print',
#   'min(list)\n    print()\nmax(list)\n    print()\nsum(list)\n    print()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'min(list)\nprint()\nmax(list)\nprint()\nsum(list)\nprint()',
#   'positive=10\nnegative=-10\nprint(abs(positive))\nprint(abs(negative))',
#   'print(min(list1))\nprint(max(list1))\nprint(sum(list1))',
#   '#Assign a variable a list containing at least 4 integers\n\nlist1=[3,12,4,67]',
# ...

# %%
#assign the output of the functions above as variables and print
#each item using a “for-loop”:

test = dir()
for i in test:
 print(i)
# Out:
# In
# Out
# _
# _13
# _14
# _16
# _2
# _21
# _22
# _23
# _24
# _25
# _3
# __
# ___
# __builtin__
# __builtins__
# __doc__
# __loader__
# __name__
# __package__
# __spec__
# _dh
# _i
# _i1
# _i10
# _i11
# _i12
# _i13
# _i14
# _i15
# _i16
# _i17
# _i18
# _i19
# _i2
# _i20
# _i21
# _i22
# _i23
# _i24
# _i25
# _i26
# _i3
# _i4
# _i5
# _i6
# _i7
# _i8
# _i9
# _ih
# _ii
# _iii
# _oh
# dict1
# exit
# get_ipython
# list
# list1
# list2
# negative
# positive
# quit
# tuple1

# %%
test = globals()
for i in test:
 print(i)
# Out:
# __name__
# __doc__
# __package__
# __loader__
# __spec__
# __builtin__
# __builtins__
# _ih
# _oh
# _dh
# In
# Out
# get_ipython
# exit
# quit
# _
# __
# ___
# _i
# _ii
# _iii
# _i1
# list
# _i2
# _2
# _i3
# _3
# _i4
# _i5
# _i6
# _i7
# _i8
# positive
# negative
# _i9
# _i10
# list1
# _i11
# _i12
# _i13
# _13
# _i14
# _14
# _i15
# _i16
# _16
# _i17
# list2
# tuple1
# dict1
# _i18
# _i19
# _i20
# _i21
# _21
# _i22
# _22
# _i23
# _23
# _i24
# _24
# _i25
# _25
# _i26
# test
# i
# _i27

# %%
test = locals()
for i in test:
 print(i)
# Out:
# __name__
# __doc__
# __package__
# __loader__
# __spec__
# __builtin__
# __builtins__
# _ih
# _oh
# _dh
# In
# Out
# get_ipython
# exit
# quit
# _
# __
# ___
# _i
# _ii
# _iii
# _i1
# list
# _i2
# _2
# _i3
# _3
# _i4
# _i5
# _i6
# _i7
# _i8
# positive
# negative
# _i9
# _i10
# list1
# _i11
# _i12
# _i13
# _13
# _i14
# _14
# _i15
# _i16
# _16
# _i17
# list2
# tuple1
# dict1
# _i18
# _i19
# _i20
# _i21
# _21
# _i22
# _22
# _i23
# _23
# _i24
# _24
# _i25
# _25
# _i26
# test
# i
# _i27
# _i28

# %%
test = vars()
for i in test:
 print(i)
# Out:
# __name__
# __doc__
# __package__
# __loader__
# __spec__
# __builtin__
# __builtins__
# _ih
# _oh
# _dh
# In
# Out
# get_ipython
# exit
# quit
# _
# __
# ___
# _i
# _ii
# _iii
# _i1
# list
# _i2
# _2
# _i3
# _3
# _i4
# _i5
# _i6
# _i7
# _i8
# positive
# negative
# _i9
# _i10
# list1
# _i11
# _i12
# _i13
# _13
# _i14
# _14
# _i15
# _i16
# _16
# _i17
# list2
# tuple1
# dict1
# _i18
# _i19
# _i20
# _i21
# _21
# _i22
# _22
# _i23
# _23
# _i24
# _24
# _i25
# _25
# _i26
# test
# i
# _i27
# _i28
# _i29

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
#Example sys
import sys

# %%
#Check the version of python: sys.version
sys.version
# Out:
# '3.11.8 (main, Mar 22 2024, 13:25:41) [MSC v.1938 64 bit (AMD64)]'

# %%
#Return the names of the Python modules that the current
#shell/kernel has imported: sys.modules
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module '_frozen_importlib' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  '_io': <module '_io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>,
#  'time': <module 'time' (built-in)>,
#  'zipimport': <module 'zipimport' (frozen)>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'codecs': <module 'codecs' (frozen)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\encodings\\aliases.py'>,
# ...

# %%
#Check the paths that the interpreter searches for modules:
#sys.path
sys.path
# Out:
# ['C:\\Users\\annab',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python311.zip',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3',
#  '',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin',
#  'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\Babel-2.11.0-py3.11.egg',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\future-0.18.3-py3.11.egg',
#  'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\Lib\\site-packages\\pytz-2022.6-py3.11.egg',
# ...

# %%
#Example os and os.path
import os
from os import path

# %%
#assign a variable the path to your “current working
#directory” using os.getcwd()
os.getcwd()
# Out:
# 'C:\\Users\\annab'

# %%
#assign a variable the filepath to a directory using
#os.path.join()
current_directory = os.getcwd()
subdirectory = "Documents"
filepath = os.path.join(current_directory, subdirectory)
print(filepath)
# Out:
# C:\Users\annab\Documents

# %%
#verify that it is a directory using os.path.isdir()
os.path.isdir(filepath)
# Out:
# True

# %%
#get the directory name using os.path.dirname()
os.path.dirname(filepath)
# Out:
# 'C:\\Users\\annab'

# %%
#get the directory “basename” using
#os.path.basename()
os.path.basename(filepath)
# Out:
# 'Documents'

# %%
#Example: shutil
import shutil

# %%
shutil.which("python")
# Out:
# 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python.EXE'

# %%
shutil.which("conda")
# Out:
# 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\Scripts\\conda.EXE'

# %%
#try to copy the directory to another location using
#shutil.copytree()
source_dir = os.path.join("C:", os.sep, "Users", "annab", "Documents", "Test_SD_Python")
destination_dir = os.path.join("C:", os.sep, "Users", "annab", "Documents", "Master CDE", "2.Semester", "Python_Copy")

# %%
#Example: math
import math

# %%
#assign a variable the value of pi (π) using the math module:
#math.pi
pi=math.pi
print(pi)
# Out:
# 3.141592653589793

# %%
#Examle: datetime
import datetime

# %%
#print the datetime object for now using
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 4, 29, 12, 4, 0, 813746)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 4, 29, 12, 5, 48, 929462)

# %%
#Example: colorsys
import colorsys

# %%
#Find an RGB color value and convert it to the HSV color
#space using colorsys.rgb_to_hsv()
colorsys.rgb_to_hsv(50, 168, 82)
# Out:
# (0.3785310734463277, 0.7023809523809523, 168)

# %%
print(os.getcwd())
# Out:
# C:\Users\annab

# %%
os.chdir(r"C:\Users\annab\Documents\Master CDE\2.Semester\Python")

# %%
print(os.getcwd())
# Out:
# C:\Users\annab\Documents\Master CDE\2.Semester\Python

# %%
#Import your module
import wham

# %%
print(wham.my_value)
print(wham.get_value())
# Out:
# 16
# 16

# %%
from wham import my_value

# %%
print(my_value)
# Out:
# 16
